# %%
import pandas as pd
import matplotlib as

# %%
df = pd.read_csv('youtubeAnalyticsData.csv')

# %%
df.head()
# Out:
#                                     title           publishedAt  viewCount  \
# 0              🔴 Raid Night ft. Subcriber  2022-01-27T18:25:49Z     642479
# 1  PUBG IN REAL LIFE ft @MortaL - Vlog 96  2022-01-25T14:30:12Z    1244606
# 2               EASIEST WAY TO PASS EXAMS  2022-01-21T14:30:16Z    4245914
# 3              CLICK HERE TO PASS EXAMS 🙏  2022-01-18T15:00:14Z    4244050
# 4  🔴short chilling w/ subscriber, manager  2022-01-17T19:07:59Z     427652
#
#    likeCount  commentCount
# 0      51217           401
# 1     106587          1112
# 2     374937          6509
# 3     374578          7490
# 4      25896           324

# %%
df = df.sort_values(by = ['viewCount'],ascending=False)

# %%
top10 = df.head(10)
top10
# Out:
#                                                  title           publishedAt  \
# 281  He Didn't See This Coming (10 Mil Surprise) @C...  2020-03-12T04:30:16Z
# 186                         MUMMY PAPA PITAI REVIEW #2  2020-07-06T15:00:14Z
# 187                                  GOODBYE TIKTOK 🙏🙏  2020-07-04T15:00:12Z
# 236                          ONLINE CLASSES GONE WRONG  2020-04-27T06:30:15Z
# 79         PAKISTANIS ARE SAVAGE PART 2 ft @Zakir Khan  2021-05-19T14:30:19Z
# 185                           GOODBYE TIKTOK - PART #2  2020-07-08T14:30:12Z
# 247  POCHINKI TOUR WITH @ashish chanchlani vines  F...  2020-04-17T05:30:02Z
# 74      PAKISTANIS ARE SAVAGE - PART 3 ft. @Zakir Khan  2021-05-28T14:30:14Z
# 81                              PAKISTANI'S ARE SAVAGE  2021-05-12T15:00:18Z
# 38   THE DHINDORA VLOG @BB Ki Vines @ashish chanchl...  2021-10-18T16:00:11Z
#
#      viewCount  likeCount  commentCount
# 281   13136400     804799          6254
# 186    9781590     513564          7182
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 1.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 52.1/52.1 KB 675.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 895.0/895.0 KB 274.9 kB/s eta 0:00:00
# ...

# %%
ax = top10.plot.bar(x = 'title', y= 'viewCount', figsize=(12,8), fontsize = 14)
# Out:
# c:\users\hp\desktop\youtube analytics project\youtubeanalytics\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128591 (\N{PERSON WITH FOLDED HANDS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
bottom10 = df.tail(10)
bottom10
# Out:
#                                                  title           publishedAt  \
# 389  Royal Turds gets a standing Ovation. Twice. So...  2013-03-31T08:12:41Z
# 377                            Late Night Chill Stream  2019-11-03T21:07:06Z
# 356  I'm a Jedi Master | Let's Plays | Star Wars Je...  2019-12-16T06:43:34Z
# 381                              8Bit Mamba Raided me!  2019-10-30T19:38:40Z
# 371  🔴 Subscriber Games | PubG Mobile | Full stream...  2019-11-16T18:51:40Z
# 384                     Playing PubG With Fans! - EP 2  2019-10-26T19:48:25Z
# 380             playing with k18 gaming and 8bitMamba!  2019-10-30T23:06:51Z
# 379              🔴 PubG with k18 gaming and 8bitMamba!  2019-10-31T01:38:09Z
# 383                    🔴 Playing PubGMobile with fans!  2019-10-27T18:07:47Z
# 382                      Playing PubGMobile with fans!  2019-10-30T04:34:00Z
#
#      viewCount  likeCount  commentCount
# 389      60087       1447            31
# 377      50016       2481            72
# ...

# %%
ax = bottom10.plot.bar(x = 'title', y= 'viewCount', figsize=(12,8), fontsize = 14)
# Out:
# c:\users\hp\desktop\youtube analytics project\youtubeanalytics\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#likes/comments
likes_avg = top10['likeCount'].mean()
comment_avg = top10['commentCount'].mean()
print('Top 10')
print('average likes', likes_avg)
print('average comments', comment_avg)
# Out:
# Top 10
# average likes 544018.3
# average comments 8581.8
